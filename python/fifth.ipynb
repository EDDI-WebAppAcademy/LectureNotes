# %%
#                       App(앱) <------------------------
#                         |                             |
# Vue(웹) <-> Spring(비즈니스 로직 처리) <-> DB(JPA)    |
#  |                      |                    |        |
#  --------------------Python <--------------------------

# %%
# !pip install flask_cors
# Out:
# Collecting flask_cors
#   Downloading Flask_Cors-3.0.10-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: Flask>=0.9 in d:\program\anaconda3\lib\site-packages (from flask_cors) (1.1.2)
# Requirement already satisfied: Six in d:\program\anaconda3\lib\site-packages (from flask_cors) (1.16.0)
# Requirement already satisfied: click>=5.1 in d:\program\anaconda3\lib\site-packages (from Flask>=0.9->flask_cors) (8.0.4)
# Requirement already satisfied: Werkzeug>=0.15 in d:\program\anaconda3\lib\site-packages (from Flask>=0.9->flask_cors) (2.0.3)
# Requirement already satisfied: itsdangerous>=0.24 in d:\program\anaconda3\lib\site-packages (from Flask>=0.9->flask_cors) (2.0.1)
# Requirement already satisfied: Jinja2>=2.10.1 in d:\program\anaconda3\lib\site-packages (from Flask>=0.9->flask_cors) (2.11.3)
# Requirement already satisfied: colorama in d:\program\anaconda3\lib\site-packages (from click>=5.1->Flask>=0.9->flask_cors) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\program\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=0.9->flask_cors) (2.0.1)
# Installing collected packages: flask-cors
# Successfully installed flask-cors-3.0.10

# %%
from flask import Flask, url_for, request, jsonify
from flask_cors import CORS, cross_origin

import json

# %%
# !python --version
# Out:
# Python 3.9.12

# %%
app = Flask(__name__)

@app.route('/python-request', methods=['GET'])
def spring2python():
    print("스프링 요청 성공!")
    data = {"spring2python Success!": True}
    
    return jsonify(data)

@app.route('/python-request-multi', methods=['GET'])
def spring2python_multi():
    data = {"Success": True}
    
    data["userId"] = "blablaId"
    data["email"] = "blablabla@gmail.com"
    
    return jsonify(data)

@app.route('/python-request-realdata', methods=['POST'])
def spring2python_realdata():
    params = json.loads(request.get_data())
    print("params: ", params)
    
    if len(params) == 0:
        return jsonify("No Parameter!")
    
    params_string = ""
    for key in params.keys():
        params_string += 'key: {}, value: {}<br>'.format(key, params[key])
    
    return jsonify(params_string)

if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [04/Oct/2022 16:47:14] "POST /python-request-realdata HTTP/1.1" 200 -
# params:  {'cost': 35000}

# %%
import pymysql
import datetime

print('start: ', str(datetime.datetime.now())[:19])
# Out:
# start:  2022-10-04 17:23:57

# %%
import pickle

MYSQL_USER_DATA_SAVED_FILE = "mysql/userinfo"

f = open(MYSQL_USER_DATA_SAVED_FILE, 'rb')
mysql_user_info = pickle.load(f)
f.close()

# %%
db = pymysql.connect(
    host = '127.0.0.1',
    port = 3306,
    user = mysql_user_info['user_id'],
    passwd = mysql_user_info['password'],
    db = 'pydb'
)

cursor = db.cursor()

sql = """
    select * from power_data
"""

cursor.execute(sql)
rows = cursor.fetchall()

db.close()
print(rows)
# Out:
# ((1, 3.24693, 2.845, 'EDDI', 'P32N21BTN77PW', datetime.datetime(2022, 9, 30, 16, 43, 58)), (2, 2.5214, 2.124, 'EDDI', 'P32N21BTN77PW', datetime.datetime(2022, 9, 30, 16, 43, 59)), (3, 3.23491, 2.84209, 'EDDI', 'P32N21BTN77PW', datetime.datetime(2022, 9, 30, 16, 44)), (4, 2.45989, 2.0717, 'EDDI', 'P32N21BTN77PW', datetime.datetime(2022, 9, 30, 16, 44, 1)), (5, 2.93042, 2.54691, 'EDDI', 'P32N21BTN77PW', datetime.datetime(2022, 9, 30, 16, 44, 2)), (6, 1.89391, 1.51513, 'EDDI', 'P32N21BTN77PW', datetime.datetime(2022, 9, 30, 16, 44, 3)), (7, 2.9829, 2.60891, 'EDDI', 'P32N21BTN77PW', datetime.datetime(2022, 9, 30, 16, 44, 4)), (8, 4.17655, 3.80739, 'EDDI', 'P32N21BTN77PW', datetime.datetime(2022, 9, 30, 16, 44, 5)), (9, 2.09897, 1.7347, 'EDDI', 'P32N21BTN77PW', datetime.datetime(2022, 9, 30, 16, 44, 6)), (10, 3.32, 2.96066, 'EDDI', 'P32N21BTN77PW', datetime.datetime(2022, 9, 30, 16, 44, 7)), (11, 4.04251, 3.68816, 'EDDI', 'P32N21BTN77PW', datetime.datetime(2022, 9, 30, 16, 44, 8)), (12, 3.68536, 3.33605, 'EDDI', 'P32N21BTN77PW', datetime.datetime(2022, 9, 30, 16, 44, 9)), (13, 2.70774, 2.36351, 'EDDI', 'P32N21BTN77PW', datetime.datetime(2022, 9, 30, 16, 44, 10)), (14, 3.03456, 2.69548, 'EDDI', 'P32N21BTN77PW', datetime.datetime(2022, 9, 30, 16, 44, 11)), (15, 2.32239, 1.9885, 'EDDI', 'P32N21BTN77PW', datetime.datetime(2022, 9, 30, 16, 44, 12)), (16, 4.55146, 4.22281, 'EDDI', 'P32N21BTN77PW', datetime.datetime(2022, 9, 30, 16, 44, 13)), (17, 2.16843, 1.84508, 'EDDI', 'P32N21BTN77PW', datetime.datetime(2022, 9, 30, 16, 44, 14)), (18, 3.22124, 2.90324, 'EDDI', 'P32N21BTN77PW', datetime.datetime(2022, 9, 30, 16, 44, 15)), (19, 2.67924, 2.36664, 'EDDI', 'P32N21BTN77PW', datetime.datetime(2022, 9, 30, 16, 44, 16)), (20, 3.52198, 3.21482, 'EDDI', 'P32N21BTN77PW', datetime.datetime(2022, 9, 30, 16, 44, 17)), (21, 2.55568, 2.25402, 'EDDI', 'P32N21BTN77PW', datetime.datetime(2022, 9, 30, 16, 44, 18)), (22, 3.15736, 2.86124, 'EDDI', 'P32N21BTN77PW', datetime.datetime(2022, 9, 30, 16, 44, 19)), (23, 1.22353, 0.933013, 'EDDI', 'P32N21BTN77PW', datetime.datetime(2022, 9, 30, 16, 44, 20)), (24, 4.88123, 4.59636, 'EDDI', 'P32N21BTN77PW', datetime.datetime(2022, 9, 30, 16, 44, 21)), (25, 2.61121, 2.33203, 'EDDI', 'P32N21BTN77PW', datetime.datetime(2022, 9, 30, 16, 44, 22)), (26, 2.25885, 1.98542, 'EDDI', 'P32N21BTN77PW', datetime.datetime(2022, 9, 30, 16, 44, 23)), (27, 0.81591, 0.548282, 'EDDI', 'P32N21BTN77PW', datetime.datetime(2022, 9, 30, 16, 44, 24)), (28, 4.08991, 3.82813, 'EDDI', 'P32N21BTN77PW', datetime.datetime(2022, 9, 30, 16, 44, 25)), (29, 2.30556, 2.04968, 'EDDI', 'P32N21BTN77PW', datetime.datetime(2022, 9, 30, 16, 44, 26)), (30, 2.49414, 2.24421, 'EDDI', 'P32N21BTN77PW', datetime.datetime(2022, 9, 30, 16, 44, 27)), (31, 3.92538, 3.68144, 'EDDI', 'P32N21BTN77PW', datetime.datetime(2022, 9, 30, 16, 44, 28)), (32, 3.42789, 3.19, 'EDDI', 'P32N21BTN77PW', datetime.datetime(2022, 9, 30, 16, 44, 29)), (33, 2.94818, 2.71639, 'EDDI', 'P32N21BTN77PW', datetime.datetime(2022, 9, 30, 16, 44, 30)), (34, 3.96212, 3.73648, 'EDDI', 'P32N21BTN77PW', datetime.datetime(2022, 9, 30, 16, 44, 31)), (35, 0.717059, 0.497612, 'EDDI', 'P32N21BTN77PW', datetime.datetime(2022, 9, 30, 16, 44, 32)), (36, 3.13151, 2.91831, 'EDDI', 'P32N21BTN77PW', datetime.datetime(2022, 9, 30, 16, 44, 33)), (37, 3.09806, 2.89116, 'EDDI', 'P32N21BTN77PW', datetime.datetime(2022, 9, 30, 16, 44, 34)), (38, 3.56854, 3.36797, 'EDDI', 'P32N21BTN77PW', datetime.datetime(2022, 9, 30, 16, 44, 35)), (39, 5.0359, 4.84173, 'EDDI', 'P32N21BTN77PW', datetime.datetime(2022, 9, 30, 16, 44, 36)), (40, 2.48438, 2.29665, 'EDDI', 'P32N21BTN77PW', datetime.datetime(2022, 9, 30, 16, 44, 37)), (41, 3.18743, 3.00619, 'EDDI', 'P32N21BTN77PW', datetime.datetime(2022, 9, 30, 16, 44, 38)), (42, 2.15466, 1.97996, 'EDDI', 'P32N21BTN77PW', datetime.datetime(2022, 9, 30, 16, 44, 39)), (43, 2.96771, 2.7996, 'EDDI', 'P32N21BTN77PW', datetime.datetime(2022, 9, 30, 16, 44, 40)), (44, 3.63744, 3.47596, 'EDDI', 'P32 ...

# %%
def db2csv():
    with open('mysql2csv.csv', 'a') as f:
        f.writelines(text[:-1] + '\n')

# %%
for x in rows:
    text = ''
    for y in x:
        y = str(y)
        text = text + y + ', '
        
    db2csv()

# %%
# !dir
# Out:
#  D 드라이브의 볼륨: 오후반_백업
#  볼륨 일련 번호: C6C5-0BFC
#
#  D:\web\python 디렉터리
#
# 2022-10-04  오후 05:27    <DIR>          .
# 2022-10-04  오후 05:27    <DIR>          ..
# 2022-10-04  오후 03:42    <DIR>          .ipynb_checkpoints
# 2022-10-04  오후 05:26             6,543 fifth.ipynb
# 2022-09-26  오후 05:33             6,340 first.ipynb
# 2022-09-30  오후 04:52            76,928 fourth.ipynb
# 2022-09-28  오후 05:25    <DIR>          mysql
# 2022-10-04  오후 05:27           682,036 mysql2csv.csv
# 2022-09-30  오후 05:44             3,775 prob_solve.ipynb
# 2022-09-27  오후 05:59            15,240 second.ipynb
# 2022-09-28  오후 05:33            38,196 third.ipynb
#                7개 파일             829,058 바이트
#                4개 디렉터리  492,543,029,248 바이트 남음

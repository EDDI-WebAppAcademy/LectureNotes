# %%
import time
import multiprocessing

# %%
def count_down(x):
    while True:
        if x == 0:
            break
            
        print("카운트 다운 ... %d" % x)
        x -= 1
        time.sleep(1)

# %%
# Mac 혹은 Linux만
p = multiprocessing.Process(target=count_down, args=(5, ))
p.start()

# %%
# Windows - 실제 구동까지 보려면 Mac 혹은 Linux여야함
if __name__ == '__main__':
    p = multiprocessing.Process(target=count_down, args=(5, ))
    print(p)
    p.start()
    p.join()
# Out:
# <Process name='Process-3' parent=12100 initial>

# %%
import threading
import os

def info():
    print('모듈명: ', __name__)
    print('프로세스 id: ', os.getpid())
    print('스레드 id: ', threading.get_ident())
    print('이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음')
    
def print_hello():
    print('안녕')
    info()
    time.sleep(1)
    print('잠자다 일어난다\n')
    
if __name__ == '__main__':
    # 현재 시간 기록
    start = time.perf_counter()
    threads = []
    
    # 스레드 5개 생성
    # 실제 컴퓨터 성능에 따라서 이 부분에 많이 혼성될 수도 있고 덜 혼성될 수도 있음
    # 컴퓨터가 압도적으로 좋거나 압도적으로 후지면 잘 혼성되지 않는다.
    for _ in range(100):
        t = threading.Thread(target = print_hello)
        t.start()
        threads.append(t)
        
    # 스레드 구동
    for thread in threads:
        thread.join()
        
    # 현재 시간 기록(현재 시간 - 이전 시간) -> 걸린 시간
    finish = time.perf_counter()
    
    print('종료: ', str(round(finish - start, 2)) + '초')
# Out:
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  9256
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  880
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  1232
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  2276
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  4324
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  12692
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  2004
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  1304
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  7728
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  2452
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  4416
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  2020
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  6452
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  10104
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  3272
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  9036
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  7572
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  11256
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  440
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  12552
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 스레드 id:  4452
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  11084
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  6884
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  4772
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  2624
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  2224
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  9576
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  11952
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  11188
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  560
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  816안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  6864
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
#
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  2540
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  12600
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  3584
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  7988
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음안녕
# 모듈명:
# 안녕
# 모듈명:  __main__
#  __main__
# 프로세스 id:  12100
# 스레드 id:  3924
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 프로세스 id:  12100
# 스레드 id:  5020
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  9476
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  9472
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  704
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  12300
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  12124
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  552
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  12132
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  5848
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  1832
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  2448
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  9676
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  4644
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  6472
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  11076
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  4400
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  10136
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  4212
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  8032
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  13048
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  8236
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  3612
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  2432
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  8764
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  9272
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  7152
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  12204
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  12796
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  13096
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  2648
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  11584
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  2152
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  9008
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  6792
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  7124
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  10572
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  4840
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  8600
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  2652
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  5156
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  8984
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  12068
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  4572
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  2988
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  8132
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  6396
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  4608
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  9644
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  1892
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  6976
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  5016
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  12460
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  464
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  10888
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  8228
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  3624
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  11480
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  252
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  12464
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  8592
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  4952
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  13052
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 안녕
# 모듈명:  __main__
# 프로세스 id:  12100
# 스레드 id:  10308
# 이런식으로 많이 집어넣으면 Context Switching도 확인할 수 있음
# 잠자다 일어난다
# 잠자다 일어난다
#
# 잠자다 일어난다
#
#
# 잠자다 일어난다
#
# 잠자다 일어난다
# 잠자다 일어난다
# 잠자다 일어난다
#
# 잠자다 일어난다
#
# 잠자다 일어난다
#
#
# 잠자다 일어난다
#
#
# 잠자다 일어난다
#
# 잠자다 일어난다
#
# 잠자다 일어난다
#
# 잠자다 일어난다
# 잠자다 일어난다
#
# 잠자다 일어난다
# 잠자다 일어난다
#
# 잠자다 일어난다
#
# 잠자다 일어난다
#
# 잠자다 일어난다
#
# 잠자다 일어난다
#
# 잠자다 일어난다
#
#
#
# 잠자다 일어난다
# 잠자다 일어난다
# 잠자다 일어난다
#
# 잠자다 일어난다
#
#
# 잠자다 일어난다
#
# 잠자다 일어난다
#
# 잠자다 일어난다
#
#
# 잠자다 일어난다
#
# 잠자다 일어난다
# 잠자다 일어난다
# 잠자다 일어난다
#
#
# 잠자다 일어난다
#
# 잠자다 일어난다
#
# 잠자다 일어난다
#
# 잠자다 일어난다
#
# 잠자다 일어난다
#
#
# 잠자다 일어난다
# 잠자다 일어난다
# 잠자다 일어난다
#
# 잠자다 일어난다
#
#
# 잠자다 일어난다
#
#
# 잠자다 일어난다
#
# 잠자다 일어난다
#
# 잠자다 일어난다
# 잠자다 일어난다
#
#
# 잠자다 일어난다
#
# 잠자다 일어난다
# 잠자다 일어난다
# 잠자다 일어난다
# 잠자다 일어난다
#
#
# 잠자다 일어난다
#
#
# 잠자다 일어난다
#
# 잠자다 일어난다
#
# 잠자다 일어난다
#
#
# 잠자다 일어난다
#
# 잠자다 일어난다
#
# 잠자다 일어난다
#
# 잠자다 일어난다
# 잠자다 일어난다
#
# 잠자다 일어난다
#
# 잠자다 일어난다
# 잠자다 일어난다
#
#
#
# 잠자다 일어난다
#
# 잠자다 일어난다
# 잠자다 일어난다
# 잠자다 일어난다
# 잠자다 일어난다
#
# 잠자다 일어난다
#
# 잠자다 일어난다
#
#
#
# 잠자다 일어난다
#
#
# 잠자다 일어난다
#
# 잠자다 일어난다
#
# 잠자다 일어난다
# 잠자다 일어난다
# 잠자다 일어난다
# 잠자다 일어난다
#
# 잠자다 일어난다
#
# 잠자다 일어난다
#
# 잠자다 일어난다
#
# 잠자다 일어난다
#
# 잠자다 일어난다
#
# 잠자다 일어난다
#
#
#
#
# 잠자다 일어난다
# 잠자다 일어난다
#
# 잠자다 일어난다
# 잠자다 일어난다
# 잠자다 일어난다
#
# 잠자다 일어난다
#
#
#
# 잠자다 일어난다
#
# 잠자다 일어난다
#
#
# 잠자다 일어난다
# 잠자다 일어난다
# 잠자다 일어난다
#
#
# 잠자다 일어난다
# 잠자다 일어난다
# 잠자다 일어난다
#
#
#
# 잠자다 일어난다
#
#
# 잠자다 일어난다
#
# 종료:  1.18초

# %%
import threading

x = 0

def increment_global():
    global x
    x += 1
    
def thread_processing():
    for _ in range(1000000):
        increment_global()
        
def thread_main():
    global x
    x = 0
    
    t1 = threading.Thread(target = thread_processing)
    t2 = threading.Thread(target = thread_processing)
    
    t1.start()
    t2.start()
    
    t1.join()
    t2.join()
    
for i in range(10):
    thread_main()
    print("{0} 번째 반복 이후 x = {1}".format(i, x))
# Out:
# 0 번째 반복 이후 x = 1524866
# 1 번째 반복 이후 x = 1709047
# 2 번째 반복 이후 x = 1848257
# 3 번째 반복 이후 x = 1720718
# 4 번째 반복 이후 x = 1737953
# 5 번째 반복 이후 x = 1429675
# 6 번째 반복 이후 x = 1852166
# 7 번째 반복 이후 x = 1552651
# 8 번째 반복 이후 x = 1581667
# 9 번째 반복 이후 x = 1567953

# %%
import threading

lock = threading.Lock()
x = 0

def increment_global():
    global x
    x += 1
    
def thread_processing():
    for _ in range(1000000):
        lock.acquire()
        increment_global()
        lock.release()
        
def thread_main():
    global x
    x = 0
    
    t1 = threading.Thread(target = thread_processing)
    t2 = threading.Thread(target = thread_processing)
    
    t1.start()
    t2.start()
    
    t1.join()
    t2.join()
    
start = time.perf_counter()
    
for i in range(10):
    thread_main()
    print("{0} 번째 반복 이후 x = {1}".format(i, x))
    
finish = time.perf_counter()
print('종료: ', str(round(finish - start, 2)) + '초')
# Out:
# 0 번째 반복 이후 x = 2000000
# 1 번째 반복 이후 x = 2000000
# 2 번째 반복 이후 x = 2000000
# 3 번째 반복 이후 x = 2000000
# 4 번째 반복 이후 x = 2000000
# 5 번째 반복 이후 x = 2000000
# 6 번째 반복 이후 x = 2000000
# 7 번째 반복 이후 x = 2000000
# 8 번째 반복 이후 x = 2000000
# 9 번째 반복 이후 x = 2000000
# 종료:  7.18초

# %%
import threading

lock = threading.Lock()
x = 0

def increment_global():
    global x
    x += 1
    
def thread_processing():
    lock.acquire()
    
    for _ in range(1000000):
        increment_global()
        
    lock.release()
        
def thread_main():
    global x
    x = 0
    
    t1 = threading.Thread(target = thread_processing)
    t2 = threading.Thread(target = thread_processing)
    
    t1.start()
    t2.start()
    
    t1.join()
    t2.join()
    
start = time.perf_counter()

for i in range(10):
    thread_main()
    print("{0} 번째 반복 이후 x = {1}".format(i, x))

finish = time.perf_counter()
print('종료: ', str(round(finish - start, 2)) + '초')
# Out:
# 0 번째 반복 이후 x = 2000000
# 1 번째 반복 이후 x = 2000000
# 2 번째 반복 이후 x = 2000000
# 3 번째 반복 이후 x = 2000000
# 4 번째 반복 이후 x = 2000000
# 5 번째 반복 이후 x = 2000000
# 6 번째 반복 이후 x = 2000000
# 7 번째 반복 이후 x = 2000000
# 8 번째 반복 이후 x = 2000000
# 9 번째 반복 이후 x = 2000000
# 종료:  2.21초

# %%
# MySQL Install
# !pip install pymysql
# Out:
# Collecting pymysql
#   Downloading PyMySQL-1.0.2-py3-none-any.whl (43 kB)
# Installing collected packages: pymysql
# Successfully installed pymysql-1.0.2

# %%
MYSQL_USER_DATA_SAVED_FILE = "mysql/userinfo"

# %%
import pickle

#mysql_user_info = dict({
#    'user_id': 'eddi',
#    'password': 'eddi@123'
#})

f = open(MYSQL_USER_DATA_SAVED_FILE, 'wb')
pickle.dump(mysql_user_info, f)
f.close()

# %%
mysql_user_info
# Out:
# {'user_id': 'eddi', 'password': 'eddi@123'}

# %%
del mysql_user_info
#mysql_user_info
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [24], in <cell line: 2>()
#       1 del mysql_user_info
# ----> 2 mysql_user_info
#
# NameError: name 'mysql_user_info' is not defined

# %%
import pickle

f = open(MYSQL_USER_DATA_SAVED_FILE, 'rb')
mysql_user_info = pickle.load(f)
f.close()

mysql_user_info
# Out:
# {'user_id': 'eddi', 'password': 'eddi@123'}

# %%
import pymysql

# 스키마 생성 - pydb
db = pymysql.connect(
    host = '127.0.0.1',
    port = 3306,
    user = mysql_user_info['user_id'],
    passwd = mysql_user_info['password'],
    db = 'pydb'
)

print(db)
# Out:
# <pymysql.connections.Connection object at 0x0000026832183AF0>

# %%
cursor = db.cursor()

sql = """
    create table pydb_test(
        id int unsigned not null auto_increment,
        name varchar(20) not null,
        price int not null,
        primary key(id)
    )
"""

cursor.execute(sql)
db.commit()
db.close()
print('테이블 생성 성공')
# Out:
# 테이블 생성 성공
